# %% [markdown]
# # This slide just has text
# We appreciate all fruits and vegetables.

# %% [markdown]
# # This slide has a jupter code cell.
# We show the input and output.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # On this slide we only show the input

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# # We hide the input on this slide

# %%
x = np.linspace(0, np.pi * 2, 100)
y = np.sin(x)
plt.plot(x, y, '-')
plt.title('This is plot')
plt.xlabel('Independent data, $\\alpha$')
plt.ylabel('Dependent data, $\\beta$');
fig = plt.gcf()
fig.dpi=100 # set a high dpi for non-blurry plots

# %% [markdown]
# # Finally, on this slide, we hide an entire cell
# Hiding cells is useful if there is certain pieces of code you want to hide.

# %%
print('someting happens here')
# Out:
# someting happens here
